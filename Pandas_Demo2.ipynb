# %% [markdown]
# <a href="https://colab.research.google.com/github/rukundob451/MachineLearning/blob/main/Pandas_Demo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 9th February 2023 Pandas-Demo2
# From toturial 4

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
filt
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 53746    False
# 53747    False
# 53748     True
# 53749     True
# 53750    False
# Name: LanguageWorkedWith, Length: 53412, dtype: bool

# %%
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 8                                 I code primarily as a hobby      Yes
# ...                                                       ...      ...
# 53738                          I am a developer by profession      Yes
# 53739                          I am a developer by profession      Yes
# 53741       I am not primarily a developer, but I write co...      Yes
# 53748                          I am a developer by profession      Yes
# 53749       I am not primarily a developer, but I write co...      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# ...

# %% [markdown]
# Toturial 5 Updating Rows and Columns

# %%
people = {
    "first": ["Benjamin", "Cory", "Dev", "Adam"],
    "last": ["Rukundo", "Doe", "Doe", "Joe"],
    "email": ["ben@xyz", "cory@xyz", "dev@xyz", "A@email.com"]
}

# %%
dff = pd.DataFrame(people)

# %%
dff
# Out:
#       first     last     email
# 0  Benjamin  Rukundo   ben@xyz
# 1      Cory      Doe  cory@xyz
# 2       Dev      Doe   dev@xyz

# %%
dff.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
dff.columns = ['first_name', 'last_name', 'email']

# %%
dff.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
dff
# Out:
#   first_name last_name     email
# 0   Benjamin   Rukundo   ben@xyz
# 1       Cory       Doe  cory@xyz
# 2        Dev       Doe   dev@xyz

# %%
dff.columns = [x.lower() for x in dff.columns]
dff
# Out:
#   first_name last_name     email
# 0   Benjamin   Rukundo   ben@xyz
# 1       Cory       Doe  cory@xyz
# 2        Dev       Doe   dev@xyz

# %%
dff.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)

# %%
dff
# Out:
#       first     last     email
# 0  Benjamin  Rukundo   ben@xyz
# 1      Cory      Doe  cory@xyz
# 2       Dev      Doe   dev@xyz

# %%
dff.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']

# %%
dff
# Out:
#       first     last                email
# 0  Benjamin  Rukundo              ben@xyz
# 1      Cory      Doe             cory@xyz
# 2      John    Smith  JohnSmith@email.com

# %%
dff.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com']

# %%
dff
# Out:
#       first     last              email
# 0  Benjamin  Rukundo            ben@xyz
# 1      Cory      Doe           cory@xyz
# 2      John      Doe  JohnDoe@email.com

# %%
dff.loc[2, ['last', 'email']] = ['Augusto', 'JohnDoe@email.com']

# %%
dff
# Out:
#       first     last              email
# 0  Benjamin  Rukundo            ben@xyz
# 1      Cory      Doe           cory@xyz
# 2      John  Augusto  JohnDoe@email.com

# %%
dff.at[2, 'last'] = 'Doe'

# %%
dff
# Out:
#       first     last              email
# 0  Benjamin  Rukundo            ben@xyz
# 1      Cory      Doe           cory@xyz
# 2      John      Doe  JohnDoe@email.com

# %%
filt = (dff['email'] == 'JohnDoe@email.com')
dff.loc[filt, 'last'] = 'Smith'

# %%
dff[filt]['last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
dff
# Out:
#       first     last              email
# 0  Benjamin  Rukundo            ben@xyz
# 1      Cory      Doe           cory@xyz
# 2      John    Smith  JohnDoe@email.com

# %%
dff['email'] = dff['email'].str.lower()

# %%
dff
# Out:
#       first     last              email
# 0  Benjamin  Rukundo            ben@xyz
# 1      Cory      Doe           cory@xyz
# 2      John    Smith  johndoe@email.com

# %% [markdown]
# 4 methods used to change multiple rows at once
# 1. apply
# 2. map
# 3. applymap
# 4. replace

# %%
dff['email'].apply(len)
# Out:
# 0     7
# 1     8
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
  return email.upper()

# %%
dff['email'] = dff['email'].apply(update_email)

# %%
dff
# Out:
#       first     last              email
# 0  Benjamin  Rukundo            BEN@XYZ
# 1      Cory      Doe           CORY@XYZ
# 2      John    Smith  JOHNDOE@EMAIL.COM

# %%
dff['email'] = dff['email'].apply(lambda x: x.lower())

# %%
dff
# Out:
#       first     last              email
# 0  Benjamin  Rukundo            ben@xyz
# 1      Cory      Doe           cory@xyz
# 2      John    Smith  johndoe@email.com

# %%
dff.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(dff['email'])
# Out:
# 3

# %%
dff.apply(pd.Series.min)
# Out:
# first    Benjamin
# last          Doe
# email     ben@xyz
# dtype: object

# %%
dff.apply(lambda x: x.min())
# Out:
# first    Benjamin
# last          Doe
# email     ben@xyz
# dtype: object

# %%
dff.applymap(len)
# Out:
#    first  last  email
# 0      8     7      7
# 1      4     3      8
# 2      4     5     17

# %%
dff.applymap(str.lower)
# Out:
#       first     last              email
# 0  benjamin  rukundo            ben@xyz
# 1      cory      doe           cory@xyz
# 2      john    smith  johndoe@email.com

# %%
dff['first'].map({'Benjamin': 'Chris', 'Corey': 'Mary'})
# Out:
# 0    Chris
# 1      NaN
# 2      NaN
# Name: first, dtype: object

# %%
dff['first'].replace({'Benjamin': 'Chris', 'Corey': 'Mary'})
# Out:
# 0    Chris
# 1     Cory
# 2     John
# Name: first, dtype: object

# %%
dff
# Out:
#       first     last              email
# 0  Benjamin  Rukundo            ben@xyz
# 1      Cory      Doe           cory@xyz
# 2      John    Smith  johndoe@email.com

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1             NaN
# 2             NaN
# 3          8820.0
# 4         61000.0
# 5             NaN
#            ...
# 53746     90072.0
# 53747    150000.0
# 53748    425000.0
# 53749     66209.0
# 53750     67200.0
# Name: SalaryUSD, Length: 53412, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 53746     No
# 53747     No
# 53748    Yes
# 53749    Yes
# 53750    Yes
# Name: Hobbyist, Length: 53412, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 53746    False
# 53747    False
# 53748     True
# 53749     True
# 53750     True
# Name: Hobbyist, Length: 53412, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 53746                          I am a developer by profession     False
# 53747                          I am a developer by profession     False
# 53748                          I am a developer by profession      True
# 53749       I am not primarily a developer, but I write co...      True
# 53750                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# Lecture 5 Add/Remove rows and columns

# %%
dff['first'] + ' ' + dff['last']
# Out:
# 0    Benjamin Rukundo
# 1            Cory Doe
# 2          John Smith
# dtype: object

# %%
dff['full_name'] = dff['first'] + ' ' + dff['last']

# %%
dff
# Out:
#       first     last              email         full_name
# 0  Benjamin  Rukundo            ben@xyz  Benjamin Rukundo
# 1      Cory      Doe           cory@xyz          Cory Doe
# 2      John    Smith  johndoe@email.com        John Smith

# %%
dff.drop(columns=['first', 'last'], inplace=True)

# %%
dff
# Out:
#                email         full_name
# 0            ben@xyz  Benjamin Rukundo
# 1           cory@xyz          Cory Doe
# 2  johndoe@email.com        John Smith

# %%
dff['full_name'].str.split(' ', expand=True)
# Out:
#           0        1
# 0  Benjamin  Rukundo
# 1      Cory      Doe
# 2      John    Smith

# %%
dff[['first', 'last']] = dff['full_name'].str.split(' ', expand=True)

# %%
dff
# Out:
#                email         full_name     first     last
# 0            ben@xyz  Benjamin Rukundo  Benjamin  Rukundo
# 1           cory@xyz          Cory Doe      Cory      Doe
# 2  johndoe@email.com        John Smith      John    Smith

# %%
dff.append({'first': 'Tony'}, ignore_index=True)
# Out:
#                email         full_name     first     last
# 0            ben@xyz  Benjamin Rukundo  Benjamin  Rukundo
# 1           cory@xyz          Cory Doe      Cory      Doe
# 2  johndoe@email.com        John Smith      John    Smith
# 3                NaN               NaN      Tony      NaN

# %%
people = {
    "first": ["Tony", "Steve"],
    "last": ["Stack", "Rogers"],
    "email": ["IronMan@avenge.com", "Cap@avenge.com"]
}
dff2 = pd.DataFrame(people)

# %%
dff2
# Out:
#    first    last               email
# 0   Tony   Stack  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
dff.append(dff2, ignore_index=True, sort=False)
# Out:
#                 email         full_name     first     last
# 0             ben@xyz  Benjamin Rukundo  Benjamin  Rukundo
# 1            cory@xyz          Cory Doe      Cory      Doe
# 2   johndoe@email.com        John Smith      John    Smith
# 3  IronMan@avenge.com               NaN      Tony    Stack
# 4      Cap@avenge.com               NaN     Steve   Rogers

# %%
dff
# Out:
#                email         full_name     first     last
# 0            ben@xyz  Benjamin Rukundo  Benjamin  Rukundo
# 1           cory@xyz          Cory Doe      Cory      Doe
# 2  johndoe@email.com        John Smith      John    Smith

# %% [markdown]
# Sorting

# %%
dff.sort_values(by='last', ascending=False)
# Out:
#                email         full_name     first     last
# 2  johndoe@email.com        John Smith      John    Smith
# 0            ben@xyz  Benjamin Rukundo  Benjamin  Rukundo
# 1           cory@xyz          Cory Doe      Cory      Doe

# %%
dff.sort_values(by=['last', 'first'], ascending=False)
# Out:
#                email         full_name     first     last
# 2  johndoe@email.com        John Smith      John    Smith
# 0            ben@xyz  Benjamin Rukundo  Benjamin  Rukundo
# 1           cory@xyz          Cory Doe      Cory      Doe

# %%
dff.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
dff
# Out:
#                email         full_name     first     last
# 2  johndoe@email.com        John Smith      John    Smith
# 0            ben@xyz  Benjamin Rukundo  Benjamin  Rukundo
# 1           cory@xyz          Cory Doe      Cory      Doe

# %%
dff.sort_index()
# Out:
#                email         full_name     first     last
# 0            ben@xyz  Benjamin Rukundo  Benjamin  Rukundo
# 1           cory@xyz          Cory Doe      Cory      Doe
# 2  johndoe@email.com        John Smith      John    Smith

# %%
dff['last'].sort_values()
# Out:
# 1        Doe
# 0    Rukundo
# 2      Smith
# Name: last, dtype: object

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 48436       Afghanistan         4464.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 29736       Afghanistan         1116.0
# 722         Afghanistan            0.0
# 28638       Afghanistan            0.0
# 6417        Afghanistan            NaN
# 7353        Afghanistan            NaN
# 12310       Afghanistan            NaN
# 26340       Afghanistan            NaN
# 29045       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 37802       Afghanistan            NaN
# 40000       Afghanistan            NaN
# 43106       Afghanistan            NaN
# 44403       Afghanistan            NaN
# 45854       Afghanistan            NaN
# 47110       Afghanistan            NaN
# 49702       Afghanistan            NaN
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 52132    2000000.0
# 32250    2000000.0
# 58       2000000.0
# 102      2000000.0
# 166      2000000.0
# 436      2000000.0
# 452      2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nsmallest(10, 'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 722                            I am a developer by profession       No
# 28638                          I am a developer by profession      Yes
# 13825                          I am a developer by profession      Yes
# 40913                          I am a developer by profession      Yes
# 30630                          I am a developer by profession      Yes
# 19340       I am not primarily a developer, but I write co...      Yes
# 16214       I am not primarily a developer, but I write co...      Yes
# 29355                          I am a developer by profession      Yes
# 1685                           I am a developer by profession      Yes
# 11875                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 722         Less than once a month but more than once per ...
# ...

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# <ipython-input-152-6d467abf240d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal        61750.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  3.373900e+04   3.366100e+04  38966.000000  30063.000000  47715.000000
# mean   9.151387e+11   1.270980e+05     42.209996      5.114335     30.359459
# std    9.441197e+13   2.831694e+05     36.988740      5.601836      9.171897
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.584800e+04     40.000000      2.000000     24.000000
# 50%    6.175000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.000000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4125.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 33661

# %%
df['Hobbyist']
# Out:
# Respondent
# 50499    Yes
# 39258    Yes
# 7085     Yes
# 22450     No
# 48436     No
#         ...
# 32960    Yes
# 48100    Yes
# 51356     No
# 51464    Yes
# 53047    Yes
# Name: Hobbyist, Length: 53412, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    42862
# No     10550
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 50499     WhatsApp
# 39258     Facebook
# 7085     Instagram
# 22450     Facebook
# 48436     Facebook
#            ...
# 32960     WhatsApp
# 48100      YouTube
# 51356     Facebook
# 51464     WhatsApp
# 53047     LinkedIn
# Name: SocialMedia, Length: 53412, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.172837
# YouTube                     0.162029
# WhatsApp                    0.158492
# Facebook                    0.155506
# Twitter                     0.136446
# Instagram                   0.073489
# I don't use social media    0.065983
# LinkedIn                    0.052032
# WeChat 微信                   0.007860
# Snapchat                    0.007231
# VK ВКонта́кте               0.006858
# Weibo 新浪微博                  0.000707
# Youku Tudou 优酷              0.000295
# Hello                       0.000236
# Name: SocialMedia, dtype: float64

# %% [markdown]
# Grouping Data

# %%
df['Country'].value_counts()
# Out:
# United States     12582
# India              5478
# Germany            3505
# United Kingdom     3447
# Canada             2021
#                   ...
# North Korea           1
# Niger                 1
# Malawi                1
# Mali                  1
# Liberia               1
# Name: Country, Length: 175, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 22013               I am a developer by profession      Yes
# 28243               I am a developer by profession      Yes
# 16793               I am a developer by profession      Yes
# 52561               I am a developer by profession      Yes
# 32536               I am a developer by profession      Yes
# ...                                            ...      ...
# 53640               I am a developer by profession      Yes
# 53698               I am a developer by profession       No
# 53701       I am a student who is learning to code      Yes
# 53716               I am a developer by profession      Yes
# 53717               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      3521
# Twitter                     2116
# Facebook                    1695
# YouTube                     1443
# I don't use social media    1100
# Instagram                    981
# LinkedIn                     589
# WhatsApp                     363
# Snapchat                     184
# WeChat 微信                     55
# Weibo 新浪微博                     7
# VK ВКонта́кте                  5
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.680000
# YouTube                     0.090667
# Weibo 新浪微博                  0.066667
# Twitter                     0.042667
# I don't use social media    0.040000
# Reddit                      0.024000
# LinkedIn                    0.018667
# Instagram                   0.010667
# Youku Tudou 优酷              0.010667
# Facebook                    0.008000
# WhatsApp                    0.005333
# VK ВКонта́кте               0.002667
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 61872.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     69468.000000
# mean      134770.280443
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('python').sum()
# Out:
# 0

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              3
# Albania                                 16
# Algeria                                 16
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    19
# Viet Nam                                54
# Yemen                                    2
# Zambia                                   1
# Zimbabwe                                11
# Name: LanguageWorkedWith, Length: 175, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States     12582
# India              5478
# Germany            3505
# United Kingdom     3447
# Canada             2021
#                   ...
# North Korea           1
# Niger                 1
# Malawi                1
# Mali                  1
# Liberia               1
# Name: Country, Length: 175, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              3
# Albania                                 16
# Algeria                                 16
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    19
# Viet Nam                                54
# Yemen                                    2
# Zambia                                   1
# Zimbabwe                                11
# Name: LanguageWorkedWith, Length: 175, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12582                6037
# India              5478                1863
# Germany            3505                1465
# United Kingdom     3447                1415
# Canada             2021                 939
# ...                 ...                 ...
# North Korea           1                   0
# Niger                 1                   1
# Malawi                1                   0
# Mali                  1                   1
# Liberia               1                   0
#
# [175 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                 NumRespondents  NumKnowsPython
# United States            12582            6037
# India                     5478            1863
# Germany                   3505            1465
# United Kingdom            3447            1415
# Canada                    2021             939
# ...                        ...             ...
# North Korea                  1               0
# Niger                        1               1
# Malawi                       1               0
# Mali                         1               1
# Liberia                      1               0
#
# [175 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                 NumRespondents  NumKnowsPython  PctKnowsPython
# United States            12582            6037       47.981243
# India                     5478            1863       34.008762
# Germany                   3505            1465       41.797432
# United Kingdom            3447            1415       41.050189
# Canada                    2021             939       46.462147
# ...                        ...             ...             ...
# North Korea                  1               0        0.000000
# Niger                        1               1      100.000000
# Malawi                       1               0        0.000000
# Mali                         1               1      100.000000
# Liberia                      1               0        0.000000
#
# [175 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %% [markdown]
# NB: inplace helps to put the necessary change inplace on the dataframe

# %%
python_df.head(50)
# Out:
#                              NumRespondents  NumKnowsPython  PctKnowsPython
# Dominica                                  1               1      100.000000
# Mali                                      1               1      100.000000
# Niger                                     1               1      100.000000
# Timor-Leste                               1               1      100.000000
# Turkmenistan                              6               5       83.333333
# Congo, Republic of the...                 5               4       80.000000
# Benin                                     4               3       75.000000
# Uganda                                   38              26       68.421053
# Guinea                                    3               2       66.666667
# Oman                                      6               4       66.666667
# Bahamas                                   3               2       66.666667
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    228.000000
# NumKnowsPython    107.000000
# PctKnowsPython     46.929825
# Name: Japan, dtype: float64
